# %% [markdown]
# # Scientific computing and machine learning in python
#
# **Python scikit-learn class 6/11/2015**
# **Material heavily borrowed from:**
# - **scipy lecture notes** (http://scipy-lectures.org)
# - **Gael's scikit-learn notebooks**
# - **Alex's scikit-learn notebooks**
#
# A lot of scientific computing is based on linear algebra in some sense. This is probably due to the fact that in a linearized setting, problems often become solvable.
#
# ## Requirements for scientific computing
#
# ### Getting data
# Requires tools to read/write data from disk easily
#
# ### Processing data
# Requires easy access to fast standard computation routines, often centered around matrix computation.
#
# What does easy access mean? There exist powerful low-level *basic linear algebra subroutines (BLAS)* and the higher level *Linear Algebra Pack (LAPACK)*, which expose many useful functions in a very little readable way:

# %%
from IPython.display import Image
Image('blas1.png')

# %%
Image('blas2.png')

# %%
Image('blas3.png')

# %% [markdown]
# Instead of
#
# `GEMM(False, False, M, N, K, 1, A, 1, B)`
#
# we would like to be able to write something like `A*B`!
#
# ### Visualizing data
# It is important to be able to visualize data, in order to better understand and follow what we are doing.
#
# ### Communicating results
# We would like to be able to generate publishable figures.
#
#
# ## Matlab does all of that

# %%
Image('matlab.jpg')

# %% [markdown]
# ## Drawbacks of Matlab
#
# - **proprietary** software, we have to pay (A LOT) for it
# - **closed source** - we can never be entirely sure what it does
# - Matlab language is not a principled programming language. Many inconsistencies
#
# ## Python/Numpy/Scipy/Sklearn
# - are free
# - are open source with a vibrant ecosystem
# - the Python language is extremely concise and is a full-fledged programming language.
